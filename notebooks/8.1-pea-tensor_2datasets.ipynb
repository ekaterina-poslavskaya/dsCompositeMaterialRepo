# %% [markdown]
# # Нейронная сеть tensorflow

# %% [markdown]
# # Итоговое задание №2. Прогнозирование конечных свойств новых материалов (композиционных материалов)
# На входе имеются данные о начальных свойствах компонентов композиционных материалов (количество связующего, наполнителя, температурный режим отверждения и т.д.). На выходе необходимо спрогнозировать ряд конечных свойств получаемых композиционных материалов.
#
# Предсказание (из семинара 22):
# * модуль упругости при растяжении
# * прочности при растяжении
# * cоотношение матрица-наполнитель
#
# Предсказание (из итогового вебинара 26.11.2022):
# * модуль упругости при растяжении
# * прочности при растяжении

# %%
import numpy as np
import pandas as pd

# %%
# считывание данных из файла
def load_simple_df(full_nm_str):
    sdf = pd.read_csv('../data/interim/'+full_nm_str+'.csv', sep=';',index_col=0) # Загрузка и создание датафрейма из csv файла
    return sdf

#считывание всех наборов для одного из целевых показателей
def load_data(nm_str):
    x_train = load_simple_df('X_train_'+nm_str)
    y_train = load_simple_df('y_train_'+nm_str)
    x_test = load_simple_df('X_test_'+nm_str)
    y_test=load_simple_df('y_test_'+nm_str)
    x_val=load_simple_df('X_val_'+nm_str)
    y_val=load_simple_df('y_val_'+nm_str)
    return (x_train, y_train, x_test, y_test, x_val, y_val)

# %% [markdown]
# Нейронная сеть

# %%
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.datasets import mnist
from tensorflow.keras import utils
from tensorflow.keras.preprocessing import image

# %%
# тренировка модели 
def try_tensor(x_train, y_train, x_val, y_val):
    tensor_model = tf.keras.Sequential()
    tensor_model.add(Dense(128, input_dim = 9, activation = 'relu'))
    tensor_model.add(Dropout(0.2))
    tensor_model.add(Dense(128, activation = 'relu'))
    tensor_model.add(Dropout(0.2))
    tensor_model.add(Dense(128, activation = 'relu'))
    tensor_model.add(Dropout(0.2))
    tensor_model.add(Dense(64, activation = 'relu'))
    tensor_model.add(Dropout(0.2))
    tensor_model.add(Dense(32, activation = 'relu'))
    tensor_model.add(Dropout(0.2))
    tensor_model.add(Dense(16, activation = 'relu'))
    tensor_model.add(Dropout(0.2))
    tensor_model.add(Dense(1, activation = 'relu'))

    #([x_train, Dense(12, activation='relu'),
    #                                Dense(128, activation='relu'),
    #                                Dense(128, activation='relu'),
    #                                Dense(128, activation='relu'),
    #                                Dense(64, activation='relu'),
    #                                Dense(32, activation='relu'),
    #                                Dense(16, activation='relu'),
    #                                Dense(1)])
    tensor_model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
                        loss='mean_squared_error')

    tensor_model.summary()
    model_hist = tensor_model.fit(x_train, y_train, epochs=70, verbose=1,
                                    validation_split = 0.2)  
    model_hist.history                                                 
    
    MSE = mean_squared_error(y_val, tensor_model.predict(x_val.values))
    R2 = r2_score(y_val, tensor_model.predict(x_val.values))

    return (MSE, R2, tensor_model, model_hist)

# %%
#запуск модели и вычисление метрик
def fit_tensor(nm_file_str, nm_error_df_str):
    #считываем данные из файлов
    x_train_df = pd.DataFrame()
    y_train_df = pd.DataFrame()
    x_test_df = pd.DataFrame()
    y_test_df = pd.DataFrame()
    x_val_df = pd.DataFrame()
    y_val_df = pd.DataFrame()

    (x_train_df, y_train_df, x_test_df, y_test_df, x_val_df, y_val_df) = load_data(nm_file_str)

    #обучаем модель
    (MSE, R2, prediction_y_tensor, hist_y_tensor) = try_tensor(x_train_df, y_train_df, x_val_df, y_val_df)
    tensor_errors = pd.DataFrame({'model_name':'Tensor',
                              'target_var':[nm_error_df_str],
                              'MSE':[MSE],
                              'R2':[R2]})
    return (tensor_errors, x_val_df, y_val_df, prediction_y_tensor, hist_y_tensor)

# %%
#визуализация
import matplotlib.pyplot as plt

def model_loss_plot(model_hist, nm_param):
    plt.figure(figsize=(17,5))
    plt.plot(model_hist.history['loss'])
    plt.plot(model_hist.history['val_loss'])
    plt.title('График потерь')
    plt.ylabel('MSE')
    plt.xlabel('Эпоха')
    plt.legend(['loss', 'val_loss'], loc='best')
    plt.show()

# %%
#визуализация
import matplotlib.pyplot as plt

def actual_and_predicted_plot(orig, predict, var, model_name):
    plt.figure(figsize=(17,5))
    plt.title(f'Валидационные и прогнозные значения: {model_name}')
    plt.plot(orig, label='Валидация')
    plt.plot(predict, label='Прогноз')
    plt.legend(loc='best')
    plt.ylabel(var)
    plt.xlabel('Количество наблюдений')
    plt.show()

# %% [markdown]
# Для каждой характеристики запускаем последовательно обучение моделей

# %%
#датасет со значениями ошибок
errors_df = pd.DataFrame(columns=['target_var','model_name','MSE','R2'])

(fit_errors, x_val_elastic, y_val_elastic, y_elastic_predict, y_elastic_hist) = fit_tensor('0_elastic', 'Модуль упругости при растяжении, ГПа')
errors_df = pd.concat([errors_df, fit_errors], ignore_index=True)
(fit_errors, x_val_strength, y_val_strength, y_strength_predict, y_strength_hist) = fit_tensor('0_strength', 'Прочность при растяжении, МПа')
errors_df = pd.concat([errors_df, fit_errors], ignore_index=True)
(fit_errors, x_val_matrix, y_val_matrix, y_matrix_predict, y_matrix_hist) = fit_tensor('0_matrix', 'Соотношение матрица-наполнитель')
errors_df = pd.concat([errors_df, fit_errors], ignore_index=True)

(fit_errors, x_val_elastic, y_val_elastic, y_elastic_predict, y_elastic_hist) = fit_tensor('90_elastic', 'Модуль упругости при растяжении, ГПа')
errors_df = pd.concat([errors_df, fit_errors], ignore_index=True)
(fit_errors, x_val_strength, y_val_strength, y_strength_predict, y_strength_hist) = fit_tensor('90_strength', 'Прочность при растяжении, МПа')
errors_df = pd.concat([errors_df, fit_errors], ignore_index=True)
(fit_errors, x_val_matrix, y_val_matrix, y_matrix_predict, y_matrix_hist) = fit_tensor('90_matrix', 'Соотношение матрица-наполнитель')
errors_df = pd.concat([errors_df, fit_errors], ignore_index=True)
errors_df
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_45 (Dense)            (None, 128)               1280
#
#  dropout_38 (Dropout)        (None, 128)               0
#
#  dense_46 (Dense)            (None, 128)               16512
#
#  dropout_39 (Dropout)        (None, 128)               0
#
#  dense_47 (Dense)            (None, 128)               16512
#
#  dropout_40 (Dropout)        (None, 128)               0
#
#  dense_48 (Dense)            (None, 64)                8256
#
#  dropout_41 (Dropout)        (None, 64)                0
#
#  dense_49 (Dense)            (None, 32)                2080
#
#  dropout_42 (Dropout)        (None, 32)                0
#
#  dense_50 (Dense)            (None, 16)                528
#
#  dropout_43 (Dropout)        (None, 16)                0
#
#  dense_51 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 45,185
# Trainable params: 45,185
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/70
# 7/7 [==============================] - 2s 45ms/step - loss: 0.1252 - val_loss: 0.0320
# Epoch 2/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0771 - val_loss: 0.0560
# Epoch 3/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0574 - val_loss: 0.0658
# Epoch 4/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0604 - val_loss: 0.0494
# Epoch 5/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0487 - val_loss: 0.0470
# Epoch 6/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0465 - val_loss: 0.0458
# Epoch 7/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0501 - val_loss: 0.0515
# Epoch 8/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0530 - val_loss: 0.0453
# Epoch 9/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0439 - val_loss: 0.0456
# Epoch 10/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0433 - val_loss: 0.0430
# Epoch 11/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0481 - val_loss: 0.0441
# Epoch 12/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0499 - val_loss: 0.0418
# Epoch 13/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0442 - val_loss: 0.0370
# Epoch 14/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0418 - val_loss: 0.0385
# Epoch 15/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0404 - val_loss: 0.0433
# Epoch 16/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0426 - val_loss: 0.0428
# Epoch 17/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0403 - val_loss: 0.0385
# Epoch 18/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0392 - val_loss: 0.0375
# Epoch 19/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0379 - val_loss: 0.0364
# Epoch 20/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0313 - val_loss: 0.0352
# Epoch 21/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0367 - val_loss: 0.0365
# Epoch 22/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0383 - val_loss: 0.0316
# Epoch 23/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0324 - val_loss: 0.0313
# Epoch 24/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0373 - val_loss: 0.0358
# Epoch 25/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0363 - val_loss: 0.0340
# Epoch 26/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0358 - val_loss: 0.0298
# Epoch 27/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0348 - val_loss: 0.0331
# Epoch 28/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0397 - val_loss: 0.0339
# Epoch 29/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0330 - val_loss: 0.0309
# Epoch 30/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0354 - val_loss: 0.0317
# Epoch 31/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0297 - val_loss: 0.0312
# Epoch 32/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0333 - val_loss: 0.0303
# Epoch 33/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0353 - val_loss: 0.0293
# Epoch 34/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0324 - val_loss: 0.0327
# Epoch 35/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0307 - val_loss: 0.0298
# Epoch 36/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0347 - val_loss: 0.0289
# Epoch 37/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0322 - val_loss: 0.0308
# Epoch 38/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0311 - val_loss: 0.0288
# Epoch 39/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0334 - val_loss: 0.0292
# Epoch 40/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0285 - val_loss: 0.0299
# Epoch 41/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0309 - val_loss: 0.0290
# Epoch 42/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0332 - val_loss: 0.0282
# Epoch 43/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0323 - val_loss: 0.0281
# Epoch 44/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0301 - val_loss: 0.0281
# Epoch 45/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0336 - val_loss: 0.0304
# Epoch 46/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0304 - val_loss: 0.0270
# Epoch 47/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0330 - val_loss: 0.0274
# Epoch 48/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0351 - val_loss: 0.0304
# Epoch 49/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0283 - val_loss: 0.0279
# Epoch 50/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0297 - val_loss: 0.0275
# Epoch 51/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0308 - val_loss: 0.0287
# Epoch 52/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0306 - val_loss: 0.0301
# Epoch 53/70
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0327 - val_loss: 0.0301
# Epoch 54/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0312 - val_loss: 0.0280
# Epoch 55/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0297 - val_loss: 0.0274
# Epoch 56/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0304 - val_loss: 0.0287
# Epoch 57/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0317 - val_loss: 0.0290
# Epoch 58/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0305 - val_loss: 0.0282
# Epoch 59/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0286 - val_loss: 0.0275
# Epoch 60/70
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0293 - val_loss: 0.0279
# Epoch 61/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0312 - val_loss: 0.0295
# Epoch 62/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0298 - val_loss: 0.0292
# Epoch 63/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0273 - val_loss: 0.0293
# Epoch 64/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0278 - val_loss: 0.0305
# Epoch 65/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0287 - val_loss: 0.0299
# Epoch 66/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0275 - val_loss: 0.0295
# Epoch 67/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0294 - val_loss: 0.0288
# Epoch 68/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0281 - val_loss: 0.0302
# Epoch 69/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0315 - val_loss: 0.0297
# Epoch 70/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0270 - val_loss: 0.0282
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_52 (Dense)            (None, 128)               1280
#
#  dropout_44 (Dropout)        (None, 128)               0
#
#  dense_53 (Dense)            (None, 128)               16512
#
#  dropout_45 (Dropout)        (None, 128)               0
#
#  dense_54 (Dense)            (None, 128)               16512
#
#  dropout_46 (Dropout)        (None, 128)               0
#
#  dense_55 (Dense)            (None, 64)                8256
#
#  dropout_47 (Dropout)        (None, 64)                0
#
#  dense_56 (Dense)            (None, 32)                2080
#
#  dropout_48 (Dropout)        (None, 32)                0
#
#  dense_57 (Dense)            (None, 16)                528
#
#  dropout_49 (Dropout)        (None, 16)                0
#
#  dense_58 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 45,185
# Trainable params: 45,185
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/70
# 7/7 [==============================] - 2s 33ms/step - loss: 0.1844 - val_loss: 0.0303
# Epoch 2/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1170 - val_loss: 0.0524
# Epoch 3/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0884 - val_loss: 0.0600
# Epoch 4/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0748 - val_loss: 0.0306
# Epoch 5/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0673 - val_loss: 0.0335
# Epoch 6/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0608 - val_loss: 0.0409
# Epoch 7/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0643 - val_loss: 0.0341
# Epoch 8/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0582 - val_loss: 0.0307
# Epoch 9/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0501 - val_loss: 0.0319
# Epoch 10/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0535 - val_loss: 0.0346
# Epoch 11/70
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0491 - val_loss: 0.0316
# Epoch 12/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0473 - val_loss: 0.0328
# Epoch 13/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0463 - val_loss: 0.0349
# Epoch 14/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0471 - val_loss: 0.0329
# Epoch 15/70
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0456 - val_loss: 0.0300
# Epoch 16/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0446 - val_loss: 0.0303
# Epoch 17/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0443 - val_loss: 0.0306
# Epoch 18/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0396 - val_loss: 0.0302
# Epoch 19/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0397 - val_loss: 0.0311
# Epoch 20/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0387 - val_loss: 0.0300
# Epoch 21/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0358 - val_loss: 0.0298
# Epoch 22/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0424 - val_loss: 0.0299
# Epoch 23/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0352 - val_loss: 0.0301
# Epoch 24/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0367 - val_loss: 0.0308
# Epoch 25/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0374 - val_loss: 0.0306
# Epoch 26/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0383 - val_loss: 0.0308
# Epoch 27/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0426 - val_loss: 0.0308
# Epoch 28/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0368 - val_loss: 0.0306
# Epoch 29/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0344 - val_loss: 0.0306
# Epoch 30/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0393 - val_loss: 0.0300
# Epoch 31/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0360 - val_loss: 0.0301
# Epoch 32/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0326 - val_loss: 0.0305
# Epoch 33/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0328 - val_loss: 0.0302
# Epoch 34/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0330 - val_loss: 0.0300
# Epoch 35/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0361 - val_loss: 0.0301
# Epoch 36/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0338 - val_loss: 0.0303
# Epoch 37/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0359 - val_loss: 0.0305
# Epoch 38/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0332 - val_loss: 0.0306
# Epoch 39/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0330 - val_loss: 0.0306
# Epoch 40/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0342 - val_loss: 0.0304
# Epoch 41/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0319 - val_loss: 0.0305
# Epoch 42/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0363 - val_loss: 0.0306
# Epoch 43/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0291 - val_loss: 0.0305
# Epoch 44/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0337 - val_loss: 0.0301
# Epoch 45/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0342 - val_loss: 0.0305
# Epoch 46/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0340 - val_loss: 0.0300
# Epoch 47/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0330 - val_loss: 0.0298
# Epoch 48/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0327 - val_loss: 0.0300
# Epoch 49/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0313 - val_loss: 0.0299
# Epoch 50/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0312 - val_loss: 0.0299
# Epoch 51/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0338 - val_loss: 0.0300
# Epoch 52/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0335 - val_loss: 0.0301
# Epoch 53/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0314 - val_loss: 0.0302
# Epoch 54/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0306 - val_loss: 0.0304
# Epoch 55/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0315 - val_loss: 0.0303
# Epoch 56/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0316 - val_loss: 0.0301
# Epoch 57/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0347 - val_loss: 0.0303
# Epoch 58/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0297 - val_loss: 0.0303
# Epoch 59/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0325 - val_loss: 0.0301
# Epoch 60/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0320 - val_loss: 0.0302
# Epoch 61/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0304 - val_loss: 0.0302
# Epoch 62/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0330 - val_loss: 0.0300
# Epoch 63/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0313 - val_loss: 0.0300
# Epoch 64/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0303 - val_loss: 0.0300
# Epoch 65/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0340 - val_loss: 0.0302
# Epoch 66/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0304 - val_loss: 0.0305
# Epoch 67/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0267 - val_loss: 0.0314
# Epoch 68/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0322 - val_loss: 0.0308
# Epoch 69/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0312 - val_loss: 0.0308
# Epoch 70/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0307 - val_loss: 0.0307
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_59 (Dense)            (None, 128)               1280
#
#  dropout_50 (Dropout)        (None, 128)               0
#
#  dense_60 (Dense)            (None, 128)               16512
#
#  dropout_51 (Dropout)        (None, 128)               0
#
#  dense_61 (Dense)            (None, 128)               16512
#
#  dropout_52 (Dropout)        (None, 128)               0
#
#  dense_62 (Dense)            (None, 64)                8256
#
#  dropout_53 (Dropout)        (None, 64)                0
#
#  dense_63 (Dense)            (None, 32)                2080
#
#  dropout_54 (Dropout)        (None, 32)                0
#
#  dense_64 (Dense)            (None, 16)                528
#
#  dropout_55 (Dropout)        (None, 16)                0
#
#  dense_65 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 45,185
# Trainable params: 45,185
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/70
# 7/7 [==============================] - 3s 50ms/step - loss: 0.2484 - val_loss: 0.1137
# Epoch 2/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1096 - val_loss: 0.0244
# Epoch 3/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0877 - val_loss: 0.0384
# Epoch 4/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0751 - val_loss: 0.0456
# Epoch 5/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0725 - val_loss: 0.0275
# Epoch 6/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0583 - val_loss: 0.0224
# Epoch 7/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0645 - val_loss: 0.0317
# Epoch 8/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0598 - val_loss: 0.0306
# Epoch 9/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0526 - val_loss: 0.0286
# Epoch 10/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0439 - val_loss: 0.0262
# Epoch 11/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0539 - val_loss: 0.0244
# Epoch 12/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0493 - val_loss: 0.0302
# Epoch 13/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0447 - val_loss: 0.0265
# Epoch 14/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0534 - val_loss: 0.0220
# Epoch 15/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0531 - val_loss: 0.0276
# Epoch 16/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0486 - val_loss: 0.0271
# Epoch 17/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0457 - val_loss: 0.0216
# Epoch 18/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0499 - val_loss: 0.0231
# Epoch 19/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0491 - val_loss: 0.0268
# Epoch 20/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0432 - val_loss: 0.0247
# Epoch 21/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0508 - val_loss: 0.0226
# Epoch 22/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0456 - val_loss: 0.0212
# Epoch 23/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0425 - val_loss: 0.0235
# Epoch 24/70
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0381 - val_loss: 0.0215
# Epoch 25/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0403 - val_loss: 0.0218
# Epoch 26/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0411 - val_loss: 0.0234
# Epoch 27/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0394 - val_loss: 0.0223
# Epoch 28/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0338 - val_loss: 0.0204
# Epoch 29/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0353 - val_loss: 0.0203
# Epoch 30/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0454 - val_loss: 0.0216
# Epoch 31/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0396 - val_loss: 0.0229
# Epoch 32/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0409 - val_loss: 0.0212
# Epoch 33/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0371 - val_loss: 0.0205
# Epoch 34/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0436 - val_loss: 0.0210
# Epoch 35/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0381 - val_loss: 0.0214
# Epoch 36/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0352 - val_loss: 0.0201
# Epoch 37/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0366 - val_loss: 0.0203
# Epoch 38/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0398 - val_loss: 0.0203
# Epoch 39/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0350 - val_loss: 0.0205
# Epoch 40/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0438 - val_loss: 0.0206
# Epoch 41/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0339 - val_loss: 0.0204
# Epoch 42/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0353 - val_loss: 0.0202
# Epoch 43/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0324 - val_loss: 0.0207
# Epoch 44/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0360 - val_loss: 0.0208
# Epoch 45/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0350 - val_loss: 0.0205
# Epoch 46/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0373 - val_loss: 0.0201
# Epoch 47/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0370 - val_loss: 0.0204
# Epoch 48/70
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0324 - val_loss: 0.0209
# Epoch 49/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0396 - val_loss: 0.0206
# Epoch 50/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0356 - val_loss: 0.0201
# Epoch 51/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0350 - val_loss: 0.0199
# Epoch 52/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0334 - val_loss: 0.0198
# Epoch 53/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0371 - val_loss: 0.0199
# Epoch 54/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0331 - val_loss: 0.0198
# Epoch 55/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0366 - val_loss: 0.0203
# Epoch 56/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0352 - val_loss: 0.0199
# Epoch 57/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0322 - val_loss: 0.0197
# Epoch 58/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0338 - val_loss: 0.0200
# Epoch 59/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0319 - val_loss: 0.0199
# Epoch 60/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0368 - val_loss: 0.0201
# Epoch 61/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0342 - val_loss: 0.0203
# Epoch 62/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0304 - val_loss: 0.0202
# Epoch 63/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0275 - val_loss: 0.0203
# Epoch 64/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0348 - val_loss: 0.0203
# Epoch 65/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0295 - val_loss: 0.0203
# Epoch 66/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0313 - val_loss: 0.0205
# Epoch 67/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0334 - val_loss: 0.0202
# Epoch 68/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0321 - val_loss: 0.0203
# Epoch 69/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0325 - val_loss: 0.0204
# Epoch 70/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0333 - val_loss: 0.0201
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_66 (Dense)            (None, 128)               1280
#
#  dropout_56 (Dropout)        (None, 128)               0
#
#  dense_67 (Dense)            (None, 128)               16512
#
#  dropout_57 (Dropout)        (None, 128)               0
#
#  dense_68 (Dense)            (None, 128)               16512
#
#  dropout_58 (Dropout)        (None, 128)               0
#
#  dense_69 (Dense)            (None, 64)                8256
#
#  dropout_59 (Dropout)        (None, 64)                0
#
#  dense_70 (Dense)            (None, 32)                2080
#
#  dropout_60 (Dropout)        (None, 32)                0
#
#  dense_71 (Dense)            (None, 16)                528
#
#  dropout_61 (Dropout)        (None, 16)                0
#
#  dense_72 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 45,185
# Trainable params: 45,185
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/70
# 7/7 [==============================] - 2s 40ms/step - loss: 0.2014 - val_loss: 0.1036
# Epoch 2/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0732 - val_loss: 0.0382
# Epoch 3/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0925 - val_loss: 0.0659
# Epoch 4/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0686 - val_loss: 0.0790
# Epoch 5/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0628 - val_loss: 0.0466
# Epoch 6/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0624 - val_loss: 0.0387
# Epoch 7/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0503 - val_loss: 0.0499
# Epoch 8/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0431 - val_loss: 0.0536
# Epoch 9/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0517 - val_loss: 0.0532
# Epoch 10/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0485 - val_loss: 0.0589
# Epoch 11/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0415 - val_loss: 0.0454
# Epoch 12/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0466 - val_loss: 0.0467
# Epoch 13/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0468 - val_loss: 0.0453
# Epoch 14/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0458 - val_loss: 0.0500
# Epoch 15/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0424 - val_loss: 0.0510
# Epoch 16/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0458 - val_loss: 0.0470
# Epoch 17/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0493 - val_loss: 0.0439
# Epoch 18/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0316 - val_loss: 0.0602
# Epoch 19/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0421 - val_loss: 0.0519
# Epoch 20/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0406 - val_loss: 0.0440
# Epoch 21/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0424 - val_loss: 0.0598
# Epoch 22/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0441 - val_loss: 0.0483
# Epoch 23/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0416 - val_loss: 0.0414
# Epoch 24/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0398 - val_loss: 0.0478
# Epoch 25/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0353 - val_loss: 0.0454
# Epoch 26/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0411 - val_loss: 0.0438
# Epoch 27/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0429 - val_loss: 0.0436
# Epoch 28/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0394 - val_loss: 0.0412
# Epoch 29/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0392 - val_loss: 0.0423
# Epoch 30/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0389 - val_loss: 0.0464
# Epoch 31/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0382 - val_loss: 0.0414
# Epoch 32/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0348 - val_loss: 0.0451
# Epoch 33/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0370 - val_loss: 0.0498
# Epoch 34/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0346 - val_loss: 0.0413
# Epoch 35/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0346 - val_loss: 0.0391
# Epoch 36/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0366 - val_loss: 0.0420
# Epoch 37/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0359 - val_loss: 0.0453
# Epoch 38/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0348 - val_loss: 0.0456
# Epoch 39/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0342 - val_loss: 0.0461
# Epoch 40/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0378 - val_loss: 0.0417
# Epoch 41/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0340 - val_loss: 0.0392
# Epoch 42/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0340 - val_loss: 0.0402
# Epoch 43/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0337 - val_loss: 0.0402
# Epoch 44/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0343 - val_loss: 0.0434
# Epoch 45/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0324 - val_loss: 0.0431
# Epoch 46/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0318 - val_loss: 0.0392
# Epoch 47/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0350 - val_loss: 0.0407
# Epoch 48/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0373 - val_loss: 0.0457
# Epoch 49/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0358 - val_loss: 0.0447
# Epoch 50/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0317 - val_loss: 0.0384
# Epoch 51/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0325 - val_loss: 0.0374
# Epoch 52/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0322 - val_loss: 0.0383
# Epoch 53/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0329 - val_loss: 0.0383
# Epoch 54/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0290 - val_loss: 0.0391
# Epoch 55/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0334 - val_loss: 0.0376
# Epoch 56/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0333 - val_loss: 0.0395
# Epoch 57/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0347 - val_loss: 0.0394
# Epoch 58/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0329 - val_loss: 0.0393
# Epoch 59/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0306 - val_loss: 0.0398
# Epoch 60/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0326 - val_loss: 0.0397
# Epoch 61/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0319 - val_loss: 0.0400
# Epoch 62/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0274 - val_loss: 0.0384
# Epoch 63/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0314 - val_loss: 0.0379
# Epoch 64/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0271 - val_loss: 0.0388
# Epoch 65/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0332 - val_loss: 0.0418
# Epoch 66/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0329 - val_loss: 0.0387
# Epoch 67/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0299 - val_loss: 0.0383
# Epoch 68/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0321 - val_loss: 0.0403
# Epoch 69/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0325 - val_loss: 0.0402
# Epoch 70/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0307 - val_loss: 0.0382
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_73 (Dense)            (None, 128)               1280
#
#  dropout_62 (Dropout)        (None, 128)               0
#
#  dense_74 (Dense)            (None, 128)               16512
#
#  dropout_63 (Dropout)        (None, 128)               0
#
#  dense_75 (Dense)            (None, 128)               16512
#
#  dropout_64 (Dropout)        (None, 128)               0
#
#  dense_76 (Dense)            (None, 64)                8256
#
#  dropout_65 (Dropout)        (None, 64)                0
#
#  dense_77 (Dense)            (None, 32)                2080
#
#  dropout_66 (Dropout)        (None, 32)                0
#
#  dense_78 (Dense)            (None, 16)                528
#
#  dropout_67 (Dropout)        (None, 16)                0
#
#  dense_79 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 45,185
# Trainable params: 45,185
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/70
# 7/7 [==============================] - 2s 39ms/step - loss: 0.2295 - val_loss: 0.0896
# Epoch 2/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1043 - val_loss: 0.0300
# Epoch 3/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0861 - val_loss: 0.0596
# Epoch 4/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0801 - val_loss: 0.0551
# Epoch 5/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0759 - val_loss: 0.0359
# Epoch 6/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0594 - val_loss: 0.0381
# Epoch 7/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0827 - val_loss: 0.0428
# Epoch 8/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0720 - val_loss: 0.0468
# Epoch 9/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0688 - val_loss: 0.0413
# Epoch 10/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0678 - val_loss: 0.0439
# Epoch 11/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0697 - val_loss: 0.0416
# Epoch 12/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0538 - val_loss: 0.0352
# Epoch 13/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0587 - val_loss: 0.0412
# Epoch 14/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0525 - val_loss: 0.0332
# Epoch 15/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0545 - val_loss: 0.0408
# Epoch 16/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0510 - val_loss: 0.0406
# Epoch 17/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0539 - val_loss: 0.0380
# Epoch 18/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0492 - val_loss: 0.0382
# Epoch 19/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0428 - val_loss: 0.0395
# Epoch 20/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0505 - val_loss: 0.0369
# Epoch 21/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0500 - val_loss: 0.0387
# Epoch 22/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0402 - val_loss: 0.0366
# Epoch 23/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0447 - val_loss: 0.0346
# Epoch 24/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0398 - val_loss: 0.0343
# Epoch 25/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0368 - val_loss: 0.0356
# Epoch 26/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0409 - val_loss: 0.0349
# Epoch 27/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0439 - val_loss: 0.0374
# Epoch 28/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0382 - val_loss: 0.0331
# Epoch 29/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0362 - val_loss: 0.0331
# Epoch 30/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0399 - val_loss: 0.0337
# Epoch 31/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0333 - val_loss: 0.0370
# Epoch 32/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0362 - val_loss: 0.0352
# Epoch 33/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0373 - val_loss: 0.0330
# Epoch 34/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0398 - val_loss: 0.0358
# Epoch 35/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0396 - val_loss: 0.0386
# Epoch 36/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0382 - val_loss: 0.0358
# Epoch 37/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0410 - val_loss: 0.0340
# Epoch 38/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0363 - val_loss: 0.0359
# Epoch 39/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0398 - val_loss: 0.0344
# Epoch 40/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0366 - val_loss: 0.0330
# Epoch 41/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0372 - val_loss: 0.0338
# Epoch 42/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0351 - val_loss: 0.0372
# Epoch 43/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0348 - val_loss: 0.0350
# Epoch 44/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0369 - val_loss: 0.0328
# Epoch 45/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0354 - val_loss: 0.0328
# Epoch 46/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0344 - val_loss: 0.0339
# Epoch 47/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0342 - val_loss: 0.0345
# Epoch 48/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0365 - val_loss: 0.0331
# Epoch 49/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0325 - val_loss: 0.0330
# Epoch 50/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0331 - val_loss: 0.0329
# Epoch 51/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0342 - val_loss: 0.0339
# Epoch 52/70
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0389 - val_loss: 0.0331
# Epoch 53/70
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0370 - val_loss: 0.0322
# Epoch 54/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0366 - val_loss: 0.0321
# Epoch 55/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0347 - val_loss: 0.0332
# Epoch 56/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0336 - val_loss: 0.0348
# Epoch 57/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0356 - val_loss: 0.0324
# Epoch 58/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0339 - val_loss: 0.0320
# Epoch 59/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0361 - val_loss: 0.0321
# Epoch 60/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0348 - val_loss: 0.0332
# Epoch 61/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0370 - val_loss: 0.0343
# Epoch 62/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0329 - val_loss: 0.0336
# Epoch 63/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0345 - val_loss: 0.0326
# Epoch 64/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0378 - val_loss: 0.0338
# Epoch 65/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0330 - val_loss: 0.0353
# Epoch 66/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0346 - val_loss: 0.0334
# Epoch 67/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0313 - val_loss: 0.0328
# Epoch 68/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0356 - val_loss: 0.0327
# Epoch 69/70
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0336 - val_loss: 0.0327
# Epoch 70/70
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0320 - val_loss: 0.0347
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 3ms/step
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_80 (Dense)            (None, 128)               1280
#
#  dropout_68 (Dropout)        (None, 128)               0
#
#  dense_81 (Dense)            (None, 128)               16512
#
#  dropout_69 (Dropout)        (None, 128)               0
#
#  dense_82 (Dense)            (None, 128)               16512
#
#  dropout_70 (Dropout)        (None, 128)               0
#
#  dense_83 (Dense)            (None, 64)                8256
#
#  dropout_71 (Dropout)        (None, 64)                0
#
#  dense_84 (Dense)            (None, 32)                2080
#
#  dropout_72 (Dropout)        (None, 32)                0
#
#  dense_85 (Dense)            (None, 16)                528
#
#  dropout_73 (Dropout)        (None, 16)                0
#
#  dense_86 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 45,185
# Trainable params: 45,185
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/70
# 7/7 [==============================] - 3s 64ms/step - loss: 0.2011 - val_loss: 0.0689
# Epoch 2/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0808 - val_loss: 0.0329
# Epoch 3/70
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0852 - val_loss: 0.0687
# Epoch 4/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0808 - val_loss: 0.0546
# Epoch 5/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0722 - val_loss: 0.0407
# Epoch 6/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0682 - val_loss: 0.0501
# Epoch 7/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0633 - val_loss: 0.0440
# Epoch 8/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0645 - val_loss: 0.0456
# Epoch 9/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0660 - val_loss: 0.0455
# Epoch 10/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0604 - val_loss: 0.0472
# Epoch 11/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0630 - val_loss: 0.0444
# Epoch 12/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0535 - val_loss: 0.0426
# Epoch 13/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0572 - val_loss: 0.0421
# Epoch 14/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0504 - val_loss: 0.0394
# Epoch 15/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0517 - val_loss: 0.0544
# Epoch 16/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0537 - val_loss: 0.0398
# Epoch 17/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0520 - val_loss: 0.0363
# Epoch 18/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0457 - val_loss: 0.0430
# Epoch 19/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0453 - val_loss: 0.0377
# Epoch 20/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0510 - val_loss: 0.0397
# Epoch 21/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0474 - val_loss: 0.0521
# Epoch 22/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0476 - val_loss: 0.0425
# Epoch 23/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0461 - val_loss: 0.0355
# Epoch 24/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0397 - val_loss: 0.0358
# Epoch 25/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0455 - val_loss: 0.0409
# Epoch 26/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0428 - val_loss: 0.0413
# Epoch 27/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0408 - val_loss: 0.0373
# Epoch 28/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0473 - val_loss: 0.0365
# Epoch 29/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0424 - val_loss: 0.0364
# Epoch 30/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0476 - val_loss: 0.0343
# Epoch 31/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0402 - val_loss: 0.0397
# Epoch 32/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0386 - val_loss: 0.0400
# Epoch 33/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0402 - val_loss: 0.0374
# Epoch 34/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0408 - val_loss: 0.0353
# Epoch 35/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0417 - val_loss: 0.0382
# Epoch 36/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0389 - val_loss: 0.0386
# Epoch 37/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0405 - val_loss: 0.0364
# Epoch 38/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0388 - val_loss: 0.0354
# Epoch 39/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0422 - val_loss: 0.0366
# Epoch 40/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0396 - val_loss: 0.0377
# Epoch 41/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0391 - val_loss: 0.0353
# Epoch 42/70
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0398 - val_loss: 0.0352
# Epoch 43/70
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0398 - val_loss: 0.0364
# Epoch 44/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0362 - val_loss: 0.0372
# Epoch 45/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0394 - val_loss: 0.0349
# Epoch 46/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0380 - val_loss: 0.0351
# Epoch 47/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0373 - val_loss: 0.0349
# Epoch 48/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0428 - val_loss: 0.0352
# Epoch 49/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0378 - val_loss: 0.0351
# Epoch 50/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0389 - val_loss: 0.0340
# Epoch 51/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0405 - val_loss: 0.0341
# Epoch 52/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0393 - val_loss: 0.0366
# Epoch 53/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0392 - val_loss: 0.0362
# Epoch 54/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0401 - val_loss: 0.0342
# Epoch 55/70
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0364 - val_loss: 0.0335
# Epoch 56/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0367 - val_loss: 0.0347
# Epoch 57/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0359 - val_loss: 0.0348
# Epoch 58/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0417 - val_loss: 0.0334
# Epoch 59/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0369 - val_loss: 0.0353
# Epoch 60/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0386 - val_loss: 0.0351
# Epoch 61/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0354 - val_loss: 0.0353
# Epoch 62/70
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0396 - val_loss: 0.0352
# Epoch 63/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0394 - val_loss: 0.0352
# Epoch 64/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0384 - val_loss: 0.0347
# Epoch 65/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0382 - val_loss: 0.0336
# Epoch 66/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0364 - val_loss: 0.0342
# Epoch 67/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0393 - val_loss: 0.0344
# Epoch 68/70
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0360 - val_loss: 0.0334
# Epoch 69/70
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0358 - val_loss: 0.0340
# Epoch 70/70
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0364 - val_loss: 0.0338
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
#                              target_var model_name       MSE        R2
# 0  Модуль упругости при растяжении, ГПа     Tensor  0.033568 -0.135939
# 1         Прочность при растяжении, МПа     Tensor  0.032627 -0.173382
# 2       Соотношение матрица-наполнитель     Tensor  0.035320 -0.084483
# 3  Модуль упругости при растяжении, ГПа     Tensor  0.025420 -0.028260
# 4         Прочность при растяжении, МПа     Tensor  0.023436  0.018249
# 5       Соотношение матрица-наполнитель     Tensor  0.032849  0.007782

# %%
model_loss_plot(y_elastic_hist, 'Модуль упругости при растяжении, ГПа')
model_loss_plot(y_strength_hist, 'Прочность при растяжении, МПа')
model_loss_plot(y_matrix_hist, 'Соотношение матрица-наполнитель')

# %%
actual_and_predicted_plot(y_val_elastic.values,
                            y_elastic_predict.predict(x_val_elastic), 
                            'Модуль упругости при растяжении, ГПа',
                            'Tensor')
#actual_and_predicted_plot(y_val_strength.values,
#                            y_strength_predict.predict(x_val_strength), 
#                            'Прочность при растяжении, МПа', 
#                            'Tensor')
#actual_and_predicted_plot(y_val_matrix.values,
#                            y_matrix_predict.predict(x_val_matrix), 
#                            'Соотношение матрица-наполнитель', 
#                            'Tensor')
# Out:
# 4/4 [==============================] - 0s 2ms/step
